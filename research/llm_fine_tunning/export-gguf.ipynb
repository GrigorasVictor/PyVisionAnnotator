# %%
TOKEN="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"

# %%
# !pip -q install --upgrade unsloth trl peft accelerate bitsandbytes

# %%
from huggingface_hub import login
from unsloth import FastLanguageModel
from peft import PeftModel
from pathlib import Path

# %%
# Where your LoRA is located
lora_dir = Path("/kaggle/input/datasets/victorgrigoras/outputqwen3-vl/outputs/lora_model")

# sanity check
print("Exists:", lora_dir.exists())
print("Files:", list(lora_dir.glob("*")))
# Out:
# Exists: True
# Files: [PosixPath('/kaggle/input/datasets/victorgrigoras/outputqwen3-vl/outputs/lora_model/adapter_model.safetensors'), PosixPath('/kaggle/input/datasets/victorgrigoras/outputqwen3-vl/outputs/lora_model/adapter_config.json'), PosixPath('/kaggle/input/datasets/victorgrigoras/outputqwen3-vl/outputs/lora_model/README.md'), PosixPath('/kaggle/input/datasets/victorgrigoras/outputqwen3-vl/outputs/lora_model/tokenizer.json'), PosixPath('/kaggle/input/datasets/victorgrigoras/outputqwen3-vl/outputs/lora_model/tokenizer_config.json'), PosixPath('/kaggle/input/datasets/victorgrigoras/outputqwen3-vl/outputs/lora_model/chat_template.jinja'), PosixPath('/kaggle/input/datasets/victorgrigoras/outputqwen3-vl/outputs/lora_model/processor_config.json')]

# %%
from huggingface_hub import login
from unsloth import FastLanguageModel

login(token=TOKEN)

LORA_DIR = "/kaggle/input/datasets/victorgrigoras/outputqwen3-vl/outputs/lora_model"
REPO_ID = "OmegaNightKing/Qwen3-vl_fine_tunned"
MAX_SEQ = 1024
DTYPE = None

# Unsloth will automatically find the base model from the adapter_config.json
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=LORA_DIR,
    max_seq_length=MAX_SEQ,
    dtype=DTYPE,
    load_in_4bit=True,
)

# Export and push directly
model.push_to_hub_gguf(
    REPO_ID,
    tokenizer,
    quantization_method="q4_k_m",
    token=TOKEN,
    temporary_location="/tmp",
)
# Out:
# ==((====))==  Unsloth 2026.5.2: Fast Qwen3_Vl patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/713 [00:00<?, ?it/s]
# Unsloth: Converting model to GGUF format...
# Unsloth: Merging model weights to 16-bit format...
# Unsloth: Restored added_tokens_decoder metadata in /tmp/unsloth_gguf_tns6msju/tokenizer_config.json.
# Found HuggingFace hub cache directory: /root/.cache/huggingface/hub
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Checking cache directory for required files...
# Cache check failed: model-00001-of-00002.safetensors not found in local cache.
# ...
